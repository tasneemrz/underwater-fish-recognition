# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# ## Importing dataset

# %%
from ultralytics import YOLO
import os

# import dataset
from roboflow import Roboflow
rf = Roboflow(api_key="*******************")
project = rf.workspace("underwater-fish").project("underwater-fish-detection-izi1l")
dataset = project.version(6).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.221, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to UnderWater-Fish-Detection-6 in yolov8:: 100%|██████████| 5450/5450 [00:01<00:00, 3016.99it/s]

# %% [markdown]
# ## Model training

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50 save_json=True save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Model validation

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data={dataset.location}/data.yaml save_json=True save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/UnderWater-Fish-Detection-6/valid/labels.cache... 377 images, 0 backgrounds, 0 corrupt: 100% 377/377 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 24/24 [00:09<00:00,  2.66it/s]
#                    all        377        449       0.99      0.985      0.993      0.895
# acanthopagrus palmaris        377        195          1      0.992      0.995      0.905
#                 caranx        377        104      0.958      0.933      0.986      0.851
#   chaetodon vagabundus        377         42      0.999          1      0.995      0.885
#            epinephelus        377         38      0.995          1      0.995      0.959
#                 gerres        377         70      0.999          1      0.995      0.874
# ...

# %% [markdown]
# # Model inference

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/UnderWater-Fish-Detection-6/test/images save_json=True save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/376 /content/UnderWater-Fish-Detection-6/test/images/7117_Caranx_sexfasciatus_juvenile_f000003_RGHS_jpg.rf.c41ade83491275abda255248ac837fe3.jpg: 640x640 3 caranxs, 25.7ms
# image 2/376 /content/UnderWater-Fish-Detection-6/test/images/7117_Caranx_sexfasciatus_juvenile_f000009_RGHS_jpg.rf.5367590534a4cefaeebdac8d293f2a91.jpg: 640x640 2 caranxs, 26.6ms
# image 3/376 /content/UnderWater-Fish-Detection-6/test/images/7117_Caranx_sexfasciatus_juvenile_f000018_RGHS_jpg.rf.5a302ec8886f5d581cfaf0e90a471a78.jpg: 640x640 3 caranxs, 21.3ms
# image 4/376 /content/UnderWater-Fish-Detection-6/test/images/7117_Caranx_sexfasciatus_juvenile_f000020_RGHS_jpg.rf.4db60c2178e88553c72cf021c3059977.jpg: 640x640 2 caranxs, 16.3ms
# ...

# %% [markdown]
# ## Model deployment

# %%
project.version(dataset.version).deploy(model_type='yolov8', model_path='/content/runs/detect/train')
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.0.221, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/underwater-fish/underwater-fish-detection-izi1l/6
# Share your model with the world at: https://universe.roboflow.com/underwater-fish/underwater-fish-detection-izi1l/model/6
